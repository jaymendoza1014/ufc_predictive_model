# %% [markdown]
# # An Evaluation on the Effectiveness of Using Machine Learning to Predict Professional Fight Outcomes
#
# This notebook tests various machine learning models ability to predict outcomes on fights in the UFC. The three models used are Logistic Regression, Random Forest, and MLP Neural Network. A baseline was also established in order to evaluate the performance. The data used to train the models was accessed on Kaggle and webscraped from the UFC stats website. The baseline models accuracy was 59%. The models that produced the highest accuracy were the Logistic Regression and MLP Neural Network models at 66%. The Random Forest Model achieved 64%.
#
# The three models were used to predict the outcomes of the UFC 300 event and all of them were able to accuratley predict 5 out of 6 fights. The 6 fights the models predictions were based off of are included below each of the models evaluation of the dataset.

# %%
import pandas as pd
import numpy as np

# %%
#importing the csv file 
ufc_data = pd.read_csv('ufc-master.csv')
ufc_data.fillna(0)

ufc_data.shape
# Out:
# (4896, 119)

# %%
#Columns that were not relevant for our analysis were dropped 
ufc_data.columns.get_loc('empty_arena')
ufc_data.drop(ufc_data.iloc[:, 77:120], inplace = True, axis = 1)
ufc_data.drop(['date', 'location', 'country', 'title_bout', 'R_ev', 'B_ev', 'weight_class', 'no_of_rounds'], axis = 1, inplace = True)
ufc_data.set_index(['R_fighter'] + ['B_fighter'] , inplace = True)

ufc_data.head()
# Out:
#                                      R_odds  B_odds Winner gender  \
# R_fighter           B_fighter
# Thiago Santos       Johnny Walker    -150.0     130    Red   MALE
# Alex Oliveira       Niko Price        170.0    -200   Blue   MALE
# Misha Cirkunov      Krzysztof Jotko   110.0    -130   Blue   MALE
# Alexander Hernandez Mike Breeden     -675.0     475    Red   MALE
# Joe Solecki         Jared Gordon     -135.0     115   Blue   MALE
#
#                                      B_current_lose_streak  \
# R_fighter           B_fighter
# Thiago Santos       Johnny Walker                        0
# Alex Oliveira       Niko Price                           2
# Misha Cirkunov      Krzysztof Jotko                      1
# Alexander Hernandez Mike Breeden                         1
# Joe Solecki         Jared Gordon                         0
#
#                                      B_current_win_streak  B_draw  \
# R_fighter           B_fighter
# Thiago Santos       Johnny Walker                       1       0
# Alex Oliveira       Niko Price                          0       0
# Misha Cirkunov      Krzysztof Jotko                     0       0
# Alexander Hernandez Mike Breeden                        0       0
# Joe Solecki         Jared Gordon                        2       0
#
#                                      B_avg_SIG_STR_landed  B_avg_SIG_STR_pct  \
# R_fighter           B_fighter
# Thiago Santos       Johnny Walker                    3.42               0.59
# Alex Oliveira       Niko Price                       5.16               0.42
# Misha Cirkunov      Krzysztof Jotko                  2.92               0.41
# Alexander Hernandez Mike Breeden                     4.04               0.34
# Joe Solecki         Jared Gordon                     5.22               0.56
#
#                                      B_avg_SUB_ATT  ...  total_round_dif  \
# R_fighter           B_fighter                       ...
# Thiago Santos       Johnny Walker              0.7  ...              -32
# Alex Oliveira       Niko Price                 0.8  ...              -20
# Misha Cirkunov      Krzysztof Jotko            0.1  ...               25
# Alexander Hernandez Mike Breeden               0.0  ...              -12
# Joe Solecki         Jared Gordon               0.0  ...               11
#
#                                      total_title_bout_dif  ko_dif  sub_dif  \
# R_fighter           B_fighter
# Thiago Santos       Johnny Walker                      -1      -7        0
# Alex Oliveira       Niko Price                          0       0       -1
# Misha Cirkunov      Krzysztof Jotko                     0       0       -5
# Alexander Hernandez Mike Breeden                        0      -2        0
# Joe Solecki         Jared Gordon                        0       1       -2
#
#                                      height_dif  reach_dif  age_dif  \
# R_fighter           B_fighter
# Thiago Santos       Johnny Walker         10.16      15.24       -8
# Alex Oliveira       Niko Price             2.54       0.00       -1
# Misha Cirkunov      Krzysztof Jotko       -5.08       0.00       -2
# Alexander Hernandez Mike Breeden           2.54      -5.08        3
# Joe Solecki         Jared Gordon           0.00      -5.08        5
#
#                                      sig_str_dif  avg_sub_att_dif  avg_td_dif
# R_fighter           B_fighter
# Thiago Santos       Johnny Walker          -0.53              0.6       -0.37
# Alex Oliveira       Niko Price              2.19              0.3       -1.48
# Misha Cirkunov      Krzysztof Jotko        -0.85             -1.6       -3.33
# Alexander Hernandez Mike Breeden            0.25              0.0       -1.57
# Joe Solecki         Jared Gordon            2.58             -0.6       -0.31
#
# [5 rows x 67 columns]

# %%
#Changing categorical variables into integers
GenderMap = {'MALE': 1, 'FEMALE': 2}
ufc_data['gender'] = ufc_data['gender'].map(GenderMap)

StanceMap = {'Orthodox': 1, 'Southpaw': 2}
ufc_data['B_Stance'] = ufc_data['B_Stance'].map(StanceMap)
ufc_data['R_Stance'] = ufc_data['R_Stance'].map(StanceMap)
ufc_data = ufc_data.fillna(0)

#Setting the winner column into a binary value column 
WinnerMap = {'Red': 1, 'Blue': 0}

# Applying the mapping to create a new 'Red Winner' column in the DataFrame
ufc_data['Red_winner'] = ufc_data['Winner'].map(WinnerMap)

# %%
# To avoid overfitting, the most relevant columns were selected 
columns = ['R_odds','gender','lose_streak_dif',
       'win_streak_dif', 'longest_win_streak_dif', 'win_dif', 'loss_dif',
       'total_round_dif', 'ko_dif', 'sub_dif',
       'height_dif', 'reach_dif', 'age_dif','avg_sub_att_dif',
       'avg_td_dif']

X = ufc_data[columns]
y = ufc_data['Red_winner']

# Transform X
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# Split data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 50)

# %% [markdown]
# # Baseline

# %%
# Dummy Classifier with baseline accuracy
from sklearn.dummy import DummyClassifier
dummy_classifier = DummyClassifier(strategy='most_frequent')
dummy_classifier.fit(X_train,y_train)
baseline_acc = dummy_classifier.score(X_train,y_train)

print("Baseline Accuracy = ", round((baseline_acc) * 100, 2), '%')
# Out:
# Baseline Accuracy =  59.32 %

# %% [markdown]
# # Logistic Regression

# %%
# Create and fit the logistic regression model here:
from sklearn.linear_model import LogisticRegression
lg_model = LogisticRegression()
lg_model.fit(X_train,y_train)

# Save and print the predicted outcomes
y_pred = lg_model.predict(X_test)
print('predicted classes: ', y_pred)

# Print out the true outcomes for the test data
print('true classes: ', y_test)

# Print out the confusion matrix
from sklearn.metrics import confusion_matrix
print('confusion matrix: ')
print(confusion_matrix(y_test, y_pred))

# Print accuracy here:
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', round((accuracy), 2) * 100, '%')
# Out:
# predicted classes:  [0 0 0 ... 0 0 0]
# true classes:  R_fighter            B_fighter
# Jason Gonzalez       JC Cottrell           1
# Christian Morecraft  Matt Mitrione         0
# Takanori Gomi        Dong Hyun Ma          0
# Volkan Oezdemir      Anthony Smith         0
# Maciej Jewtuszko     Curt Warburton        0
#                                           ..
# Hannah Cifers        Jodie Esquibel        1
# Albert Morales       Andre Soukhamthath    1
# Aleksei Oleinik      Curtis Blaydes        0
# Tito Ortiz           Matt Hamill           0
# Garreth McLellan     Alessio Di Chirico    0
# Name: Red_winner, Length: 1469, dtype: int64
# confusion matrix:
# [[338 305]
#  [195 631]]
# Accuracy: 66.0 %

# %%
import joblib

joblib.dump(lg_model, 'lg_model.pk1')
# Out:
# ['lg_model.pk1']

# %% [markdown]
# ## UFC Model predictions
# 1. Davidson Figueiredo vs Cody Garbrandt
# 2. Bo Nickal vs Cody Brundage
# 3. Justin Gaethje vs Max Holloway
# 4. Charles Oliveira vs Arman Tsarukyan
# 5. Zhang Weili vs Yan Xiaonan
# 6. Alex Pereira vs Jamahal Hill

# %%
data = np.array([
    [-200, 1, 0, -1, -1, 23, -3, 12, -2, 3, -7.63, 7.62, 4, 1.7, 0.62],
    [-1450, 1, 0, 4, 4, 4, -6, -10, -2, 2, 2.54, 10.16, -1, 6.6, 5.13],
    [-162, 1, 0, 0, -9, -2, -3, -65, -4, -2, 0, 2.54, 3, -0.3, -0.14],
    [120, 1, 0, -2, 6, 13, 6, 35, 0, 17, 7.62, 5.08, 7, 2.8, -1.08],
    [-250, 2, 0, 1, -1, 6, 0, -1, 1, 2, -2.53, 0, 0, 0.5, 1.51],
    [-125, 1, 0, -2, 0, -3, 2, -3, -1, 0, 0, 0, 4, 0.4, 0.18]
])

predictions = lg_model.predict(data)
print("Predictions:", predictions)
# Out:
# Predictions: [1 1 1 0 1 1]

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 200, random_state = 0)

classifier.fit(X_train, y_train)

rfc_score = classifier.score(X_test, y_test)
print('The Random Forest Model accuracy is:', round(rfc_score, 2) * 100, '%')
# Out:
# The Random Forest Model accuracy is: 64.0 %

# %% [markdown]
# ## UFC Model predictions
# 1. Davidson Figueiredo vs Cody Garbrandt
# 2. Bo Nickal vs Cody Brundage
# 3. Justin Gaethje vs Max Holloway
# 4. Charles Oliveira vs Arman Tsarukyan
# 5. Zhang Weili vs Yan Xiaonan
# 6. Alex Pereira vs Jamahal Hill

# %%
data = np.array([
    [-200, 1, 0, -1, -1, 23, -3, 12, -2, 3, -7.63, 7.62, 4, 1.7, 0.62],
    [-1450, 1, 0, 4, 4, 4, -6, -10, -2, 2, 2.54, 10.16, -1, 6.6, 5.13],
    [-162, 1, 0, 0, -9, -2, -3, -65, -4, -2, 0, 2.54, 3, -0.3, -0.14],
    [120, 1, 0, -2, 6, 13, 6, 35, 0, 17, 7.62, 5.08, 7, 2.8, -1.08],
    [-250, 2, 0, 1, -1, 6, 0, -1, 1, 2, -2.53, 0, 0, 0.5, 1.51],
    [-125, 1, 0, -2, 0, -3, 2, -3, -1, 0, 0, 0, 4, 0.4, 0.18]
])

predictions = classifier.predict(data)
print("Predictions:", predictions)
# Out:
# Predictions: [1 1 1 1 1 1]

# %% [markdown]
# # Deep Learning (Multi-Layer Perceptron)

# %%
from sklearn.compose import ColumnTransformer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, InputLayer
from sklearn.metrics import classification_report
from tensorflow.keras.utils import to_categorical


mlp_model = Sequential()
mlp_model.add(InputLayer(shape = (X_train.shape[1],)))
mlp_model.add(Dense(12, activation = 'relu'))
mlp_model.add(Dense(1, activation = 'sigmoid'))

mlp_model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

#Train and evaluate 

mlp_model.fit(X_train, y_train, epochs = 100, batch_size = 16, verbose = 1)

loss, acc = model.evaluate(X_test, y_test, verbose = 0)

y_estimate = model.predict(X_test, verbose = 0)
y_estimate = (y_estimate > 0.5).astype(int)
y_true = y_test


print(y_true)
print(classification_report(y_true, y_estimate))
# Out:
# Epoch 1/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - accuracy: 0.5318 - loss: 0.7011
# Epoch 2/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - accuracy: 0.6037 - loss: 0.6456
# Epoch 3/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - accuracy: 0.6140 - loss: 0.6385
# Epoch 4/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 294us/step - accuracy: 0.6410 - loss: 0.6258
# Epoch 5/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - accuracy: 0.6441 - loss: 0.6285
# Epoch 6/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - accuracy: 0.6604 - loss: 0.6143
# Epoch 7/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - accuracy: 0.6502 - loss: 0.6185
# Epoch 8/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - accuracy: 0.6655 - loss: 0.6135
# Epoch 9/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - accuracy: 0.6477 - loss: 0.6209
# Epoch 10/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - accuracy: 0.6440 - loss: 0.6237
# Epoch 11/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - accuracy: 0.6540 - loss: 0.6071
# Epoch 12/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - accuracy: 0.6632 - loss: 0.6083
# Epoch 13/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - accuracy: 0.6627 - loss: 0.6174
# Epoch 14/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 303us/step - accuracy: 0.6325 - loss: 0.6211
# Epoch 15/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - accuracy: 0.6427 - loss: 0.6174
# Epoch 16/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - accuracy: 0.6623 - loss: 0.6101
# Epoch 17/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - accuracy: 0.6494 - loss: 0.6102
# Epoch 18/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - accuracy: 0.6501 - loss: 0.6070
# Epoch 19/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 304us/step - accuracy: 0.6425 - loss: 0.6153
# Epoch 20/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - accuracy: 0.6395 - loss: 0.6212
# Epoch 21/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 302us/step - accuracy: 0.6724 - loss: 0.5912
# Epoch 22/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 309us/step - accuracy: 0.6427 - loss: 0.6153
# Epoch 23/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - accuracy: 0.6560 - loss: 0.6006
# Epoch 24/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - accuracy: 0.6491 - loss: 0.6146
# Epoch 25/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - accuracy: 0.6560 - loss: 0.6063
# Epoch 26/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - accuracy: 0.6611 - loss: 0.6036
# Epoch 27/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - accuracy: 0.6688 - loss: 0.5939
# Epoch 28/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step - accuracy: 0.6568 - loss: 0.6096
# Epoch 29/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - accuracy: 0.6634 - loss: 0.5970
# Epoch 30/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 296us/step - accuracy: 0.6469 - loss: 0.6163
# Epoch 31/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - accuracy: 0.6697 - loss: 0.5991
# Epoch 32/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - accuracy: 0.6617 - loss: 0.6049
# Epoch 33/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - accuracy: 0.6615 - loss: 0.6004
# Epoch 34/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.6434 - loss: 0.6155
# Epoch 35/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - accuracy: 0.6790 - loss: 0.5867
# Epoch 36/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.6640 - loss: 0.6026
# Epoch 37/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - accuracy: 0.6695 - loss: 0.5925
# Epoch 38/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 294us/step - accuracy: 0.6560 - loss: 0.6072
# Epoch 39/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - accuracy: 0.6733 - loss: 0.5916
# Epoch 40/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 293us/step - accuracy: 0.6623 - loss: 0.5985
# Epoch 41/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - accuracy: 0.6489 - loss: 0.6125
# Epoch 42/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.6766 - loss: 0.5905
# Epoch 43/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - accuracy: 0.6685 - loss: 0.5970
# Epoch 44/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - accuracy: 0.6613 - loss: 0.6032
# Epoch 45/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - accuracy: 0.6659 - loss: 0.5933
# Epoch 46/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 293us/step - accuracy: 0.6644 - loss: 0.6034
# Epoch 47/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 285us/step - accuracy: 0.6659 - loss: 0.5948
# Epoch 48/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 293us/step - accuracy: 0.6649 - loss: 0.6073
# Epoch 49/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 289us/step - accuracy: 0.6659 - loss: 0.5998
# Epoch 50/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - accuracy: 0.6703 - loss: 0.5940
# Epoch 51/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - accuracy: 0.6538 - loss: 0.6120
# Epoch 52/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - accuracy: 0.6561 - loss: 0.6003
# Epoch 53/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 293us/step - accuracy: 0.6694 - loss: 0.5978
# Epoch 54/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 287us/step - accuracy: 0.6512 - loss: 0.6004
# Epoch 55/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - accuracy: 0.6652 - loss: 0.5993
# Epoch 56/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 293us/step - accuracy: 0.6761 - loss: 0.5946
# Epoch 57/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - accuracy: 0.6594 - loss: 0.6011
# Epoch 58/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 289us/step - accuracy: 0.6461 - loss: 0.6139
# Epoch 59/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step - accuracy: 0.6701 - loss: 0.5941
# Epoch 60/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 296us/step - accuracy: 0.6749 - loss: 0.5893
# Epoch 61/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 296us/step - accuracy: 0.6797 - loss: 0.5911
# Epoch 62/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.6808 - loss: 0.5989
# Epoch 63/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 294us/step - accuracy: 0.6636 - loss: 0.6005
# Epoch 64/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step - accuracy: 0.6725 - loss: 0.5993
# Epoch 65/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - accuracy: 0.6718 - loss: 0.5940
# Epoch 66/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 293us/step - accuracy: 0.6836 - loss: 0.5888
# Epoch 67/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - accuracy: 0.6695 - loss: 0.6006
# Epoch 68/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 294us/step - accuracy: 0.6646 - loss: 0.6001
# Epoch 69/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step - accuracy: 0.6656 - loss: 0.6038
# Epoch 70/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 306us/step - accuracy: 0.6767 - loss: 0.5926
# Epoch 71/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - accuracy: 0.6779 - loss: 0.5941
# Epoch 72/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 290us/step - accuracy: 0.6738 - loss: 0.6008
# Epoch 73/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 435us/step - accuracy: 0.6722 - loss: 0.5963
# Epoch 74/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - accuracy: 0.6584 - loss: 0.5998
# Epoch 75/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.6709 - loss: 0.5983
# Epoch 76/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step - accuracy: 0.6759 - loss: 0.5903
# Epoch 77/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - accuracy: 0.6772 - loss: 0.5970
# Epoch 78/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - accuracy: 0.6657 - loss: 0.6077
# Epoch 79/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 296us/step - accuracy: 0.6680 - loss: 0.6024
# Epoch 80/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 290us/step - accuracy: 0.6764 - loss: 0.5871
# Epoch 81/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 301us/step - accuracy: 0.6761 - loss: 0.5947
# Epoch 82/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.6687 - loss: 0.5955
# Epoch 83/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 285us/step - accuracy: 0.6748 - loss: 0.5890
# Epoch 84/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - accuracy: 0.6801 - loss: 0.5986
# Epoch 85/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - accuracy: 0.6695 - loss: 0.5994
# Epoch 86/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - accuracy: 0.6782 - loss: 0.5925
# Epoch 87/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.6589 - loss: 0.6006
# Epoch 88/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - accuracy: 0.6762 - loss: 0.5953
# Epoch 89/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - accuracy: 0.6759 - loss: 0.5887
# Epoch 90/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 293us/step - accuracy: 0.6794 - loss: 0.5916
# Epoch 91/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.6641 - loss: 0.6016
# Epoch 92/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 296us/step - accuracy: 0.6717 - loss: 0.5955
# Epoch 93/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 294us/step - accuracy: 0.6838 - loss: 0.5850
# Epoch 94/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step - accuracy: 0.6772 - loss: 0.5897
# Epoch 95/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step - accuracy: 0.6574 - loss: 0.6050
# Epoch 96/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 290us/step - accuracy: 0.6686 - loss: 0.5989
# Epoch 97/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 295us/step - accuracy: 0.6766 - loss: 0.5924
# Epoch 98/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - accuracy: 0.6715 - loss: 0.5970
# Epoch 99/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - accuracy: 0.6733 - loss: 0.5867
# Epoch 100/100
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - accuracy: 0.6625 - loss: 0.5961
# R_fighter            B_fighter
# Jason Gonzalez       JC Cottrell           1
# Christian Morecraft  Matt Mitrione         0
# Takanori Gomi        Dong Hyun Ma          0
# Volkan Oezdemir      Anthony Smith         0
# Maciej Jewtuszko     Curt Warburton        0
#                                           ..
# Hannah Cifers        Jodie Esquibel        1
# Albert Morales       Andre Soukhamthath    1
# Aleksei Oleinik      Curtis Blaydes        0
# Tito Ortiz           Matt Hamill           0
# Garreth McLellan     Alessio Di Chirico    0
# Name: Red_winner, Length: 1469, dtype: int64
#               precision    recall  f1-score   support
#
#            0       0.61      0.53      0.57       643
#            1       0.67      0.74      0.70       826
#
#     accuracy                           0.65      1469
#    macro avg       0.64      0.63      0.63      1469
# weighted avg       0.64      0.65      0.64      1469

# %% [markdown]
# ## UFC Model predictions
# 1. Davidson Figueiredo vs Cody Garbrandt
# 2. Bo Nickal vs Cody Brundage
# 3. Justin Gaethje vs Max Holloway
# 4. Charles Oliveira vs Arman Tsarukyan
# 5. Zhang Weili vs Yan Xiaonan
# 6. Alex Pereira vs Jamahal Hill

# %%
data = np.array([
    [-200, 1, 0, -1, -1, 23, -3, 12, -2, 3, -7.63, 7.62, 4, 1.7, 0.62],
    [-1450, 1, 0, 4, 4, 4, -6, -10, -2, 2, 2.54, 10.16, -1, 6.6, 5.13],
    [-162, 1, 0, 0, -9, -2, -3, -65, -4, -2, 0, 2.54, 3, -0.3, -0.14],
    [120, 1, 0, -2, 6, 13, 6, 35, 0, 17, 7.62, 5.08, 7, 2.8, -1.08],
    [-250, 2, 0, 1, -1, 6, 0, -1, 1, 2, -2.53, 0, 0, 0.5, 1.51],
    [-125, 1, 0, -2, 0, -3, 2, -3, -1, 0, 0, 0, 4, 0.4, 0.18]
])

predictions = model.predict(data)
print("Predictions:", predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Predictions: [[1.0000000e+00]
#  [1.0000000e+00]
#  [1.0000000e+00]
#  [1.6863964e-31]
#  [1.0000000e+00]
#  [1.0000000e+00]]
